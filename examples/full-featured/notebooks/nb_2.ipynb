# %%
# %load_ext autoreload
# %autoreload 2

# %%
from dj.nb_op import standalone_context
from my_op.cfg import Nb2Cfg
context = standalone_context(Nb2Cfg(b=30), ins_run_id="0000")

# %% [markdown]
# ### 1. Defines a notebook as a dagster operation

# %%
from dj.nb_op import NbOp    

op = NbOp(
    context=context,
    ins=[
         'data0',
         'data1',
         'data3',
    ],
    outs=['data4']
)

# %% [markdown]
#  ### 2. Initialize an op context and ins paths variables

# %% [markdown]
# ### A body

# %%
op.ins_run_id

# %%
op.outs.data4
op.ins.data3

# %%
context.op_config

# %%
op.cfg.b

# %%
context.log.info(context.op_config)
