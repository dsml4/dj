# %%
# %load_ext autoreload
# %autoreload 2

# %%
import jupyter_black

jupyter_black.load()

# %%
from pydantic import Field
import dagster as dg
from dj.nb_op import standalone_context

class Nb1Cfg(dg.Config):
    a: int = Field(description="this is the paramentr description", default=10)

context = standalone_context(Nb1Cfg(a=30))
print(context.job_name)

# %%
from dj.nb_op import NbOp

op = NbOp(
    context=context,
    outs=["data1", "data2", "data3"],
)

# %% [markdown]
# ### A body

# %%
# op.set_context(context)
op.outs.data1

# %%
op.cfg

# %%
context.log.info(context.op_config)
